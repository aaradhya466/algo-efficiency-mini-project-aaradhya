# %%
from memory_profiler import memory_usage
import time
import matplotlib.pyplot as plt
import random

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr

def profile_bubble_sort():
    sizes = [100, 500, 1000, 2000]
    times, mems = [], []

    for n in sizes:
        arr = random.sample(range(1, n*10), n)

        start = time.time()
        mem = memory_usage((bubble_sort, (arr.copy(),)), max_iterations=1, interval=0.01)
        end = time.time()

        times.append(end - start)
        mems.append(max(mem) - min(mem))

    plt.plot(sizes, times, label="Time (s)")
    plt.plot(sizes, mems, label="Memory (MB)")
    plt.xlabel("Input size (n)")
    plt.legend()
    plt.title("Bubble Sort Performance")
    plt.show()

profile_bubble_sort()
