# %%
from memory_profiler import memory_usage
import time
import matplotlib.pyplot as plt
import random

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr

def profile_insertion_sort():
    sizes = [100, 500, 1000, 2000]
    times, mems = [], []

    for n in sizes:
        arr = random.sample(range(1, n*10), n)

        start = time.time()
        mem = memory_usage((insertion_sort, (arr.copy(),)), max_iterations=1, interval=0.01)
        end = time.time()

        times.append(end - start)
        mems.append(max(mem) - min(mem))

    plt.plot(sizes, times, label="Time (s)")
    plt.plot(sizes, mems, label="Memory (MB)")
    plt.xlabel("Input size (n)")
    plt.legend()
    plt.title("Insertion Sort Performance")
    plt.show()

profile_insertion_sort()
